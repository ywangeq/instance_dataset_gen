# %%
import os
import glob
import random

# %%
data = 'Kitti'
data_store = 'npydata'
label_store = 'npylabel'
root =os.getcwd()
print(root)
# Out:
# /usr/app/code/data

# %%
data_path = os.path.join(root,data,data_store)
label_path = os.path.join(root,data,label_store)

# %%
if not os.path.exists(data_path):
    print('no path exist')
    os.makedirs(data_path)
if not os.path.exists(data_path):
    os.makedirs(data_path)
    print('no path exist')

# %%
train = open('train.txt','w')
val = open('valid.txt','w')

# %%
file_path=os.path.join(data_path,'*.npy')
file_P = glob.glob(file_path)
L=len(file_P)
random.shuffle(file_P)
train_len = int(L*0.8)

for i in file_P[:train_len]:
    key = i[19:]
    type_,data,name = key.split('/')
    data_path = os.path.join(root,type_,data,name)
    label_path = os.path.join(root,type_,'npylabel',name)
#     print(data_path)
#     print(label_path)
    if os.path.exists(data_path) and os.path.exists(label_path):
        print('generate ok')
    train.write(data_path)
    train.write(' ')
    train.write(label_path)
    train.write('\n')
# Out:
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# ...

# %%
for i in file_P[train_len:]:
    key = i[19:]
    type_,data,name = key.split('/')
    data_path = os.path.join(root,type_,data,name)
    label_path = os.path.join(root,type_,'npylabel',name)
#     print(data_path)
#     print(label_path)
    if os.path.exists(data_path) and os.path.exists(label_path):
        print('generate ok')
    val.write(data_path)
    val.write(' ')
    val.write(label_path)
    val.write('\n')
# Out:
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# generate ok
# ...
